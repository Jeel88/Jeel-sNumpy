# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeel88/Jeel-sNumpy/blob/main/07_vectorization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
arr = np.array([10, 20, 30, 40])
result = (arr * 2)
print(result)
# Out:
# [20 40 60 80]

# %%
arr = np.array([10, 20, 30, 40])
print(arr + 5)
# Out:
# [15 25 35 45]

# %%
arr = np.array([
    [10, 20, 30],
    [40, 50, 60]
])
print(arr * 2)
# Out:
# [[ 20  40  60]
#  [ 80 100 120]]

# %%
arr=np.array([[[1,2,3],[4,5,6]],[[1,2,3],[4,5,6]]])
print(arr+2)
# Out:
# [[[3 4 5]
#   [6 7 8]]
#
#  [[3 4 5]
#   [6 7 8]]]
