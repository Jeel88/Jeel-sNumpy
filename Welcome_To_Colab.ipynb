# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeel88/Jeel-sNumpy/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
print("testing github")
# Out:
# testing github
